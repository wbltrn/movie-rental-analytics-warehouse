# %%
import os
os.chdir("Desktop/movie-rental-analytics-warehouse")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import os
# ----> 2 os.chdir("Desktop/movie-rental-analytics-warehouse")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Desktop/movie-rental-analytics-warehouse'

# %%
# !pwd
# Out:
# /Users/wilibeltran/Desktop/CourseFolders/DS2002/Midterm Project/movie-rental-analytics-warehouse/src

# %%
import os

os.environ["MYSQL_USER"] = "root"
os.environ["MYSQL_PASSWORD"] = "%Blancab27"
os.environ["MYSQL_HOST"] = "localhost"
os.environ["MYSQL_PORT"] = "3306"
os.environ["MYSQL_DATABASE"] = "sakila"

# %%
# !python transform.py
# Out:
# Transformation complete.
#
# dim_customer: (599, 10)
#    customer_key  customer_id  ...            city        country
# 0             1            1  ...          Sasebo          Japan
# 1             2            2  ...  San Bernardino  United States
# 2             3            3  ...         Athenai         Greece
# 3             4            4  ...        Myingyan        Myanmar
# 4             5            5  ...          Nantou         Taiwan
#
# [5 rows x 10 columns]
#
# dim_film: (1000, 9)
#    film_key  film_id             title  ...  length  replacement_cost  rating
# 0         1        1  ACADEMY DINOSAUR  ...      86             20.99      PG
# 1         2        2    ACE GOLDFINGER  ...      48             12.99       G
# 2         3        3  ADAPTATION HOLES  ...      50             18.99   NC-17
# 3         4        4  AFFAIR PREJUDICE  ...     117             26.99       G
# 4         5        5       AFRICAN EGG  ...     130             22.99       G
#
# ...

# %%
# !python etl_pipeline.py
# Out:
# Starting ETL pipeline...
# Loading dimension tables...
# Loading fact table...
# Data successfully loaded into warehouse.
# ETL pipeline complete.
